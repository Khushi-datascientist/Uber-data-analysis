# %%
import pandas as pd 
data=pd.read_csv(r"C:\Users\finis\Downloads\uber data.csv")
data.head()
# Out:
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
import pandas as pd 
data=pd.read_csv(r"C:\Users\finis\Downloads\uber data.csv")
data.head(15)
# Out:
#           START_DATE          END_DATE  CATEGORY              START  \
# 0   01-01-2016 21:11  01-01-2016 21:17  Business        Fort Pierce
# 1   01-02-2016 01:25  01-02-2016 01:37  Business        Fort Pierce
# 2   01-02-2016 20:25  01-02-2016 20:38  Business        Fort Pierce
# 3   01-05-2016 17:31  01-05-2016 17:45  Business        Fort Pierce
# 4   01-06-2016 14:42  01-06-2016 15:49  Business        Fort Pierce
# 5   01-06-2016 17:15  01-06-2016 17:19  Business    West Palm Beach
# 6   01-06-2016 17:30  01-06-2016 17:35  Business    West Palm Beach
# 7   01-07-2016 13:27  01-07-2016 13:33  Business               Cary
# 8   01-10-2016 08:05  01-10-2016 08:25  Business               Cary
# 9   01-10-2016 12:17  01-10-2016 12:44  Business            Jamaica
# 10  01-10-2016 15:08  01-10-2016 15:51  Business           New York
# 11  01-10-2016 18:18  01-10-2016 18:53  Business           Elmhurst
# 12  01-10-2016 19:12  01-10-2016 19:32  Business            Midtown
# ...

# %%
data.tail()
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES         PURPOSE
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
data.shape
# Out:
# (1156, 7)

# %%
data.tail(15)
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 1141  12/29/2016 19:50  12/29/2016 20:10  Business  Unknown Location
# 1142  12/29/2016 20:15  12/29/2016 20:45  Business           Kar?chi
# 1143  12/29/2016 20:53  12/29/2016 21:42  Business           Kar?chi
# 1144  12/29/2016 23:14  12/29/2016 23:47  Business  Unknown Location
# 1145  12/30/2016 10:15  12/30/2016 10:33  Business           Kar?chi
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Kar?chi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Kar?chi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Kar?chi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# ...

# %%
data.isnull()
# Out:
#       START_DATE  END_DATE  CATEGORY  START   STOP  MILES  PURPOSE
# 0          False     False     False  False  False  False    False
# 1          False     False     False  False  False  False     True
# 2          False     False     False  False  False  False    False
# 3          False     False     False  False  False  False    False
# 4          False     False     False  False  False  False    False
# ...          ...       ...       ...    ...    ...    ...      ...
# 1151       False     False     False  False  False  False    False
# 1152       False     False     False  False  False  False    False
# 1153       False     False     False  False  False  False    False
# 1154       False     False     False  False  False  False    False
# 1155       False      True      True   True   True  False     True
#
# [1156 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# START_DATE      0
# END_DATE        1
# CATEGORY        1
# START           1
# STOP            1
# MILES           0
# PURPOSE       503
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 507

# %% [markdown]
# #filling the null values

# %%
data2=data.fillna(value=0)

# %%
data2=data.fillna(value=0)
data2
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals                 0         0                 0
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
data2.isnull().sum().sum()
# Out:
# 0

# %%
#for example- if we need to fill the null values will previous record 
#we can use the word called'pad'
#lets replace the null values instead of changing the original data set

# %%
data3=data.fillna(method='pad')
data3
# Out:
# C:\Users\finis\AppData\Local\Temp\ipykernel_2668\713231795.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3=data.fillna(method='pad')
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# ...

# %%
data3.isnull().sum()
# Out:
# START_DATE    0
# END_DATE      0
# CATEGORY      0
# START         0
# STOP          0
# MILES         0
# PURPOSE       0
# dtype: int64

# %%
#filling null values will next values and we will use the method called bfill

# %%
data4=data.fillna(method="bfill")
data4
# Out:
# C:\Users\finis\AppData\Local\Temp\ipykernel_2668\597614838.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data4=data.fillna(method="bfill")
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# ...

# %%
# filling different values in null in different columns

# %%
data6=data.fillna({'PURPOSE':'abc'})
data6
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
#filling null values using mean values of a particular columns

# %%
data7=data.fillna(value=data['MILES'].mean())
data7
# Out:
#             START_DATE          END_DATE   CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17   Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37   Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38   Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45   Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49   Business       Fort Pierce
# ...                ...               ...        ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42   Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38   Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50   Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51   Business           Gampaha
# 1155            Totals         21.115398  21.115398         21.115398
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
data8=data.fillna(value=data['MILES'].max())
data8
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals           12204.7   12204.7           12204.7
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
data9=data.fillna(value=data['MILES'].min())
data9
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               0.5       0.5               0.5
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# #dropping null values

# %%
data10=data.dropna()
data10
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 5     01-06-2016 17:15  01-06-2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %%
data10=data.dropna()
data10
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 5     01-06-2016 17:15  01-06-2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %%
data11=data.dropna(how='all')
data11
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
data12=data.dropna(how='any')
data12
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 5     01-06-2016 17:15  01-06-2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %% [markdown]
# #repalcing null values

# %%
import numpy as np
data13 = data.replace(to_replace = np.nan,value = 12340)
data13
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals             12340     12340             12340
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
#intrerpolate- uses different values to intrerpolsate the values  and also includes various types

# %%
data['MILES'] = data['MILES'].interpolate(method='linear')
data
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
data['MILES'] = data['MILES'].interpolate(method='linear',limit_direction='forward')
data
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
#duplicate

# %%
data['MILES'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1151     True
# 1152     True
# 1153     True
# 1154    False
# 1155    False
# Name: MILES, Length: 1156, dtype: bool

# %%
data['PURPOSE'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1151     True
# 1152     True
# 1153     True
# 1154     True
# 1155     True
# Name: PURPOSE, Length: 1156, dtype: bool

# %%
data['START_DATE'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1151    False
# 1152    False
# 1153    False
# 1154    False
# 1155    False
# Name: START_DATE, Length: 1156, dtype: bool

# %%
data['END_DATE'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1151    False
# 1152    False
# 1153    False
# 1154    False
# 1155    False
# Name: END_DATE, Length: 1156, dtype: bool

# %%
data['START'].duplicated()
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1151     True
# 1152     True
# 1153    False
# 1154    False
# 1155    False
# Name: START, Length: 1156, dtype: bool

# %%
data['CATEGORY'].duplicated()
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1151     True
# 1152     True
# 1153     True
# 1154     True
# 1155    False
# Name: CATEGORY, Length: 1156, dtype: bool

# %%
data['CATEGORY'].duplicated().sum()
# Out:
# 1153

# %%
data['MILES'].duplicated().sum()
# Out:
# 899

# %%
data['START'].duplicated().sum()
# Out:
# 978

# %%
data['START_DATE'].duplicated().sum()
# Out:
# 1

# %%
data['END_DATE'].duplicated().sum()
# Out:
# 1

# %%
data['PURPOSE'].duplicated().sum()
# Out:
# 1145

# %%
data.drop_duplicates()
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
data19= data.drop_duplicates(subset=['PURPOSE'])
data19
# Out:
#            START_DATE          END_DATE  CATEGORY             START  \
# 0    01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1    01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2    01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3    01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4    01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 13   01-11-2016 08:55  01-11-2016 09:21  Business       East Harlem
# 76   02-06-2016 16:20  02-06-2016 16:53  Business              Cary
# 558   7/17/2016 11:23   7/17/2016 11:50  Personal        Banner Elk
# 559   7/17/2016 12:20   7/17/2016 15:25  Personal             Boone
# 560   7/18/2016 10:37   7/18/2016 10:49  Personal              Cary
# 683   8/21/2016 10:00   8/21/2016 10:29  Business  Unknown Location
#
#                  STOP  MILES          PURPOSE
# 0         Fort Pierce    5.1   Meal/Entertain
# 1         Fort Pierce    5.0              NaN
# ...

# %%
data20= data.drop_duplicates(subset=['START','STOP'])
data20
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 5     01-06-2016 17:15  01-06-2016 17:19  Business   West Palm Beach
# 6     01-06-2016 17:30  01-06-2016 17:35  Business   West Palm Beach
# 7     01-07-2016 13:27  01-07-2016 13:33  Business              Cary
# ...                ...               ...       ...               ...
# 1122  12/27/2016 14:49  12/27/2016 15:03  Business           Kar?chi
# 1123  12/27/2016 16:34  12/27/2016 16:58  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES         PURPOSE
# 0          Fort Pierce      5.1  Meal/Entertain
# ...

# %%
data21= data.drop_duplicates(subset=['START','STOP'],keep='last')
data21
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 5     01-06-2016 17:15  01-06-2016 17:19  Business   West Palm Beach
# 6     01-06-2016 17:30  01-06-2016 17:35  Business   West Palm Beach
# 10    01-10-2016 15:08  01-10-2016 15:51  Business          New York
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES         PURPOSE
# 3          Fort Pierce      4.7         Meeting
# ...

# %%
#importing necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import calendar
import datetime

# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\finis\Downloads\uber data.csv")
data.head()
# Out:
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
data.boxplot(column='MILES')
# Out:
# <Axes: >

# %%
Q1=data['MILES'].quantile(.25)
Q3=data['MILES'].quantile(.75)
IQR=Q3-Q1

lower_bound=Q1-1.5 *IQR
upper_bound=Q1+1.5 *IQR
data[data['MILES']>upper_bound]
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 9     01-10-2016 12:17  01-10-2016 12:44  Business           Jamaica
# 22    01-12-2016 16:02  01-12-2016 17:00  Business          New York
# 25     1/14/2016 16:29   1/14/2016 17:05  Business           Houston
# 34     1/20/2016 10:36   1/20/2016 11:11  Business              Cary
# ...                ...               ...       ...               ...
# 1089  12/22/2016 15:40  12/22/2016 16:38  Business  Unknown Location
# 1092  12/22/2016 17:56  12/22/2016 18:29  Business  Unknown Location
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES         PURPOSE
# 4      West Palm Beach     63.7  Customer Visit
# ...

# %%
data.dtypes
# Out:
# START_DATE     object
# END_DATE       object
# CATEGORY       object
# START          object
# STOP           object
# MILES         float64
# PURPOSE        object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
from datetime import datetime

date_string = '01-01-2016 21:11'
date_format = '%d-%m-%Y %H:%M'

# Parse the date string using the correct format
parsed_date = datetime.strptime(date_string, date_format)
print(parsed_date)
# Out:
# 2016-01-01 21:11:00

# %%
import pandas as pd

data = {'date_column': ['2024-08-26', '2023-07-13', '2024-12-01']}
df = pd.DataFrame(data)

print("Before conversion:", df['date_column'].dtype)

df['date_column'] = pd.to_datetime(df['date_column'])

print("After conversion:", df['date_column'].dtype)
# Out:
# Before conversion: object
# After conversion: datetime64[ns]

# %%
import pandas as pd
import calendar

# Assuming data['START_DATE'] is already a datetime column
data = pd.DataFrame({
    'START_DATE': pd.to_datetime(['2024-08-26 14:30:00', '2023-07-13 08:15:00', '2024-12-01 16:45:00'])
})

# Directly extracting datetime components
data['HOUR'] = data['START_DATE'].dt.hour
data['DAY'] = data['START_DATE'].dt.day
data['DAYOFWEEK'] = data['START_DATE'].dt.dayofweek
data['MONTH'] = data['START_DATE'].dt.month
data['WEEKDAY'] = data['START_DATE'].dt.day_name()

print(data)
# Out:
#            START_DATE  HOUR  DAY  DAYOFWEEK  MONTH   WEEKDAY
# 0 2024-08-26 14:30:00    14   26          0      8    Monday
# 1 2023-07-13 08:15:00     8   13          3      7  Thursday
# 2 2024-12-01 16:45:00    16    1          6     12    Sunday

# %%
import pandas as pd
import calendar
import matplotlib.pyplot as plt
# Assuming data['START_DATE'] is already a datetime column
data = pd.DataFrame({
    'START_DATE': pd.to_datetime(['2024-08-26 14:30:00', '2023-07-13 08:15:00', '2024-12-01 16:45:00'])
})

# Directly extracting datetime components
data['HOUR'] = data['START_DATE'].dt.hour
data['DAY'] = data['START_DATE'].dt.day
data['DAYOFWEEK'] = data['START_DATE'].dt.dayofweek
data['MONTH'] = data['START_DATE'].dt.month
data['WEEKDAY'] = data['START_DATE'].dt.day_name()

print(data)
data['MONTH'].value_counts().plot(kind='bar',figsize=(10,5),color='pink')
# Out:
#            START_DATE  HOUR  DAY  DAYOFWEEK  MONTH   WEEKDAY
# 0 2024-08-26 14:30:00    14   26          0      8    Monday
# 1 2023-07-13 08:15:00     8   13          3      7  Thursday
# 2 2024-12-01 16:45:00    16    1          6     12    Sunday
# <Axes: xlabel='MONTH'>

# %%
#size

# %%
data.size
# Out:
# 8092

# %%
data.describe()
# Out:
#               MILES
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
#printing all the data which has trhe starting point as san francisco
data[data['START']=='San Francisco']
# Out:
#            START_DATE          END_DATE  CATEGORY          START        STOP  \
# 362  05-09-2016 14:39  05-09-2016 15:06  Business  San Francisco   Palo Alto
# 440   6/14/2016 16:09   6/14/2016 16:39  Business  San Francisco  Emeryville
# 836  10/19/2016 14:02  10/19/2016 14:31  Business  San Francisco    Berkeley
# 917  11-07-2016 19:17  11-07-2016 19:57  Business  San Francisco    Berkeley
# 919  11-08-2016 12:16  11-08-2016 12:49  Business  San Francisco    Berkeley
# 927  11-09-2016 18:40  11-09-2016 19:17  Business  San Francisco     Oakland
# 933  11-10-2016 15:17  11-10-2016 15:22  Business  San Francisco     Oakland
# 966  11/15/2016 20:44  11/15/2016 21:00  Business  San Francisco    Berkeley
#
#      MILES          PURPOSE
# 362   20.5  Between Offices
# 440   11.6          Meeting
# 836   10.8              NaN
# 917   13.2  Between Offices
# 919   11.3          Meeting
# 927   12.7   Customer Visit
# 933    9.9   Temporary Site
# 966   11.8   Temporary Site

# %%
#extarcting the most popular stsarting point of uber drivers
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv(r"C:\Users\finis\Downloads\uber data.csv")
a=data['START'].dropna()
data=pd.DataFrame(a.value_counts())
data.sort_values(['START'],ascending=False)
data=data.reset_index()
data=data.rename(columns={'index':'starting_destination','START':'Count'})
data.loc[data['Count']==max(data['Count'])]
# Out:
#              Count  count
# 107  Winston Salem      1

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv(r"C:\Users\finis\Downloads\uber data.csv")
a=data['START'].dropna()
data=pd.DataFrame(a.value_counts())
data.sort_values(['START'],ascending=False)
data=data.reset_index()
data=data.rename(columns={'index':'starting_destination','START':'Count'})
data.loc[data['Count']==min(data['Count'])]
# Out:
#     Count  count
# 41  Agnew      4

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv(r"C:\Users\finis\Downloads\uber data.csv")
data=pd.DataFrame(data['MILES'].groupby(data['PURPOSE']).sum())
data.plot(kind= 'bar')
plt.show()

# %%
 
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv(r"C:\Users\finis\Downloads\uber data.csv")
data=pd.DataFrame(data['MILES'].groupby(data['START_DATE']).sum())
data.plot(kind= 'bar')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your Uber dataset
file_path = r'C:/Users/finis/Downloads/uber data.csv'  # Use raw string to avoid issues with backslashes
df = pd.read_csv(file_path)

# Select relevant columns for the heatmap (e.g., numerical columns)
numerical_cols = ['MILES']  # Add other numerical columns if available

# Calculate the correlation matrix
corr_matrix = df[numerical_cols].corr()

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
import matplotlib.pyplot as plt
data=pd.read_csv(r"C:\Users\finis\Downloads\uber data.csv")

data.plot(kind='bar')
data=pd.DataFrame(data['CATEGORY'].value_counts())
data.reset_index()
plt.plot(kind='bar')                 
plt.show()
data
# Out:
#           count
# CATEGORY
# Business   1078
# Personal     77

# %%
#category we have:
data['CATEGORY'].value_counts()
# Out:
# CATEGORY
# Business    1078
# Personal      77
# Name: count, dtype: int64

# %%
#how long people travel with uber
import matplotlib.pyplot as  plt
import pandas as pd
import seaborn as sns
data=pd.read_csv(r"C:/Users/finis/Downloads/uber data.csv")
data['MILES'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#purpose of a trip
import pandas as pd
import matplotlib.pyplot as plt

data = pd.DataFrame({
    'PURPOSE': ['Business', 'Leisure', 'Leisure', 'Business', 'Leisure', 'Business', 'Commute', 'Leisure', 'Commute']
})

data['PURPOSE'].value_counts().plot(kind='bar', figsize=(10, 5), color='brown')

plt.xlabel('Purpose of Trip')
plt.ylabel('Frequency')
plt.title('Frequency of Trip Purposes')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.DataFrame({
    'WEEKDAY': [' sunday', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday','saturday']
})

data['WEEKDAY'].value_counts().plot(kind='bar', figsize=(10, 5), color='purple')

plt.xlabel('WEEKDAY')
plt.ylabel('Frequency')
plt.title('WEEKDAY')
plt.show()

# %%
 import pandas as pd
import matplotlib.pyplot as plt

data = pd.DataFrame({'START': ['Cary', 'Midtown East', 'New York', 'Fort Pierce', 'West Palm Beach', 'Jamaica', 'Elmhurst', 'Midtown', 'Hudson Square']
})

data['START'].value_counts().plot(kind='bar', figsize=(10, 5), color='blue')

plt.xlabel('START')
plt.ylabel('MILES')
plt.title('START')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Load the dataset
data = pd.read_csv('C:/Users/finis/Downloads/uber data.csv')

# Convert 'START_DATE' and 'END_DATE' to datetime format
data['START_DATE'] = pd.to_datetime(data['START_DATE'], format="%m/%d/%Y %H:%M", errors='coerce')
data['END_DATE'] = pd.to_datetime(data['END_DATE'], format="%m/%d/%Y %H:%M", errors='coerce')

# Drop rows with NaT in 'START_DATE' or 'END_DATE'
data = data.dropna(subset=['START_DATE', 'END_DATE'])

# Calculate the trip duration in minutes
data['trip_duration'] = (data['END_DATE'] - data['START_DATE']).dt.total_seconds() / 60.0

# Drop the original datetime columns
data = data.drop(['START_DATE', 'END_DATE'], axis=1)

# Convert categorical columns to numerical format using one-hot encoding
data = pd.get_dummies(data, columns=['CATEGORY', 'START', 'STOP', 'PURPOSE'])

# Define the target and features
X = data.drop('MILES', axis=1)  # Features (excluding 'MILES')
y = data['MILES']  # Target variable

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train the models
# Model 1: Linear Regression
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

# Model 2: Random Forest Regressor
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train, y_train)

# Evaluate the models
# Predictions on the test set
y_pred_lr = lr_model.predict(X_test)
y_pred_rf = rf_model.predict(X_test)

# Evaluation Metrics for Linear Regression
mse_lr = mean_squared_error(y_test, y_pred_lr)
r2_lr = r2_score(y_test, y_pred_lr)

# Evaluation Metrics for Random Forest Regressor
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

# Print the results
print("Linear Regression - MSE: {:.2f}, R^2: {:.2f}".format(mse_lr, r2_lr))
print("Random Forest - MSE: {:.2f}, R^2: {:.2f}".format(mse_rf, r2_rf))

# Select the best model based on MSE
if mse_lr < mse_rf:
    print("Linear Regression performs better based on MSE.")
else:
    print("Random Forest performs better based on MSE.")
# Out:
# Linear Regression - MSE: 2337057942476546375680.00, R^2: -3538709787978201600.00
# Random Forest - MSE: 175.93, R^2: 0.73
# Random Forest performs better based on MSE.
